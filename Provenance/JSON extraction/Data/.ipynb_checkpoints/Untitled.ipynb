# %%
import json
import ijson
import pandas as pd
import numpy as np
import prov
import matplotlib as plt

#definition of contents
document = pd.read_json('KOAPROV.json')
# print(document)
Bundles = document["bundle"]
provenance = Bundles["result:provenance"]
elementoverview = list(provenance)

#pandas dataframe
df = pd.DataFrame(provenance)
print(df)
# plt.show(df)

# print(df.count())
# Out:
#                                                                                              activity  \
# result:commit-0056839002a2a4b74b235871a43404895...                  {'prov:label': 'Release v0.10.3'}
# result:commit-0056839002a2a4b74b235871a43404895...                                                NaN
# result:commit-0056839002a2a4b74b235871a43404895...                                                NaN
# result:commit-0056839002a2a4b74b235871a43404895...                                                NaN
# result:commit-0056839002a2a4b74b235871a43404895...                                                NaN
# result:commit-00b239725586f5af81546314cd674c103...                   {'prov:label': 'Default values'}
# result:commit-00b239725586f5af81546314cd674c103...                                                NaN
# result:commit-00b239725586f5af81546314cd674c103...                                                NaN
# ...

# %%
# generation = provenance['wasGeneratedBy']
# # print(generation)
# file = json.loads(generation)
# # print(file)
# # time = file['prov:time']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-324cafb17047> in <module>()
#       1 generation = provenance['wasGeneratedBy']
#       2 # print(generation)
# ----> 3 file = json.loads(generation)
#       4 # print(file)
#       5 # time = file['prov:time']
#
# /Users/dylienneevery/anaconda/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346         if not isinstance(s, (bytes, bytearray)):
#     347             raise TypeError('the JSON object must be str, bytes or bytearray, '
# --> 348                             'not {!r}'.format(s.__class__.__name__))
#     349         s = s.decode(detect_encoding(s), 'surrogatepass')
#     350
#
# TypeError: the JSON object must be str, bytes or bytearray, not 'dict'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-d6463dd43bf4> in <module>()
# ----> 1 df['wasStartedBy'].contains("prov:activity")
#
# /Users/dylienneevery/anaconda/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'contains'
